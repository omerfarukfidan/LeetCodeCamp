# %%
"""
https://leetcode.com/problems/3sum/description/
15. 3Sum
Medium
Topics
Companies
Hint
Given an integer array nums, return all the triplets [nums[i], nums[j], nums[k]] such that i != j, i != k, and j != k, and nums[i] + nums[j] + nums[k] == 0.

Notice that the solution set must not contain duplicate triplets.



Example 1:

Input: nums = [-1,0,1,2,-1,-4]
Output: [[-1,-1,2],[-1,0,1]]
Explanation:
nums[0] + nums[1] + nums[2] = (-1) + 0 + 1 = 0.
nums[1] + nums[2] + nums[4] = 0 + 1 + (-1) = 0.
nums[0] + nums[3] + nums[4] = (-1) + 2 + (-1) = 0.
The distinct triplets are [-1,0,1] and [-1,-1,2].
Notice that the order of the output and the order of the triplets does not matter.
Example 2:

Input: nums = [0,1,1]
Output: []
Explanation: The only possible triplet does not sum up to 0.
Example 3:

Input: nums = [0,0,0]
Output: [[0,0,0]]
Explanation: The only possible triplet sums up to 0.


Constraints:

3 <= nums.length <= 3000
-105 <= nums[i] <= 105


"""

# %%
#BENİM YARIM ÇÖZÜMÜM DOĞRU DEĞİL
class Solution:
    def threeSum(self, nums: List[int]) -> List[List[int]]:
        i, j, k = 0, 1, 2
        result = []
        nums.sort()
        for l in range(len(nums)):
            if k != len(nums):
                if  nums[i]+nums[j]+nums[k] == 0:
                    result.append([nums[i],nums[j],nums[k]])

                    k += 1
                elif k == j+1:
                    i = j
                    j += 1
                else:
                    j = k
                    k +=1


        return result


#watch after minute 1.12.20

# %%
#VIDEO SOLUTION
class Solution:
    def threeSum(self, nums: List[int]) -> List[List[int]]:

        nums.sort()
        triplets = []
        for indx, value in enumerate(nums):
            if (indx > 0) and (value == nums[indx-1]): #UNDERSTAND WHY
                continue

            left = indx +1
            right = len(nums)-1

            while left < right:

                currentSum = value + nums[left] + nums[right]

                if currentSum > 0:
                    right -= 1
                elif currentSum < 0:
                    left += 1
                else:
                    triplets.append([value, nums[left], nums[right]])
                    left += 1

                    while (left<right) and (nums[left]==nums[left-1]): #UNDERSTAND WHY
                        left += 1


        return triplets
